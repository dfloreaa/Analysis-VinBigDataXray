# %%
from functions import Datos
from ipywidgets import interact, interactive, IntSlider, ToggleButtons

# %%
Data = Datos()
# Out:
# Cargando ejemplos de patologías...
# ...............

# %%
Data.df_summary("train")
# Out:
# TRAIN SET
# TOTAL: 67914 samples
#      Nombre de la Clase  N° de Samples % del Total
# 0    Aortic enlargement           7162       10.5%
# 1           Atelectasis            279        0.4%
# 2         Calcification            960        1.4%
# 3          Cardiomegaly           5427        8.0%
# 4         Consolidation            556        0.8%
# 5                   ILD           1000        1.5%
# 6   Aortic Infiltration           1247        1.8%
# 7          Lung Opacity           2483        3.7%
# 8           Nodule/Mass           2580        3.8%
# 9          Other lesion           2203        3.2%
# 10     Pleural effusion           2476        3.6%
# 11   Pleural thickening           4842        7.1%
# 12         Pneumothorax            226        0.3%
# 13   Pulmonary fibrosis           4655        6.9%
# 14           No finding          31818       46.9%

# %%
Data.plot_summary("train")
# Out:
# <BarContainer object of 15 artists>

# %%
Data.filter_id(0, "train")
# Out:
#                                image_id          class_name  class_id rad_id  \
# 3      051132a778e61a86eb147c7c6f564dfe  Aortic enlargement         0    R10
# 8      d3637a1935a905b3c326af31389cb846  Aortic enlargement         0    R10
# 14     321c111713c3ee5385db0effb54ff568  Aortic enlargement         0     R8
# 18     5da264775732004f1b724b660138854a  Aortic enlargement         0     R9
# 19     fb8e11c6b2886b2d41b379e0598669b9  Aortic enlargement         0    R10
# ...                                 ...                 ...       ...    ...
# 67871  cf32a2bc41deeb7436a36bcc4ff324fb  Aortic enlargement         0    R11
# 67873  b41fd5f3e08360e72cc4d73a83a1b610  Aortic enlargement         0    R10
# 67885  f4da0959856bcdd4b91e0c6949b109e3  Aortic enlargement         0     R9
# 67887  8ef3fb1b703ffcb77d3709d45adf8695  Aortic enlargement         0     R8
# 67888  c75f825862144dbdff940d9c4ecccde8  Aortic enlargement         0     R8
#
#         x_min  y_min   x_max   y_max
# ...

# %%
interact(Data.ejemplo, id_clase_raw = (0, 14), num_ejemplo = (0,4))
# Out:
# interactive(children=(IntSlider(value=7, description='id_clase_raw', max=14), IntSlider(value=0, description='…
# <function ipywidgets.widgets.interaction._InteractFactory.__call__.<locals>.<lambda>(*args, **kwargs)>

# %%
interact(Data.distribucion_pixeles, id_clase_raw = (0, 14), num_ejemplo = (0,4))
# Out:
# interactive(children=(IntSlider(value=7, description='id_clase_raw', max=14), IntSlider(value=0, description='…
# <function ipywidgets.widgets.interaction._InteractFactory.__call__.<locals>.<lambda>(*args, **kwargs)>
